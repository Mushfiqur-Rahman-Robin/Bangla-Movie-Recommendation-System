# %%
import numpy as np
import pandas as pd

# %%
movies = pd.read_csv(r'C:\Users\USER\Desktop\Bangla-Movie-Recommendation-System\BanglaMovieDataset.csv')
movies.head()
# Out:
#          id                       title           genre  \
# 0   5331886                 Dhaka Dream           Drama
# 1   4853244               Rickshaw Girl          Family
# 2  15756034  Khachar Bhitor Ochin Pakhi        Thriller
# 3  15547790                  The Broker  Drama Thriller
# 4  13770656                 August 1975         History
#
#                                             overview  runtime  \
# 0  Dhaka Dream is a tale of a city where outlying...      120
# 1  A Bangladeshi girl bravely attempts to help he...      102
# 2  In the game of politics, power dynamic can cha...      113
# 3  A poor man working as a broker struggles to ar...       47
# 4  The film portrays the initial events of the ra...      100
#
#                                                actor  \
# 0  Purnima Bristi| Anwar Hossain Chowdhury| Fazlu...
# 1           Allen Shubhro| Siam Ahmed| Novera Rahman
# 2     Fazlur Rahman Babu| Toma Mirza| Intekhab Dinar
# ...

# %%
movies['rating'].fillna(round((movies['rating'].mean()),1), inplace=True)
movies.head()
# Out:
#          id                       title           genre  \
# 0   5331886                 Dhaka Dream           Drama
# 1   4853244               Rickshaw Girl          Family
# 2  15756034  Khachar Bhitor Ochin Pakhi        Thriller
# 3  15547790                  The Broker  Drama Thriller
# 4  13770656                 August 1975         History
#
#                                             overview  runtime  \
# 0  Dhaka Dream is a tale of a city where outlying...      120
# 1  A Bangladeshi girl bravely attempts to help he...      102
# 2  In the game of politics, power dynamic can cha...      113
# 3  A poor man working as a broker struggles to ar...       47
# 4  The film portrays the initial events of the ra...      100
#
#                                                actor  \
# 0  Purnima Bristi| Anwar Hossain Chowdhury| Fazlu...
# 1           Allen Shubhro| Siam Ahmed| Novera Rahman
# 2     Fazlur Rahman Babu| Toma Mirza| Intekhab Dinar
# ...

# %%
import ast
def Convertgenre(string):
    li = list(string.split(" "))
    return li

# %%
for i in range(0, len(movies)):
    str1 = Convertgenre(movies['genre'][i])
    #print(Convert(str1)) 
    #print(str1) 
    movies['genre'][i] = str1
# Out:
# C:\Users\USER\AppData\Local\Temp/ipykernel_11948/1836914483.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['genre'][i] = str1

# %%
movies.head()
# Out:
#          id                       title              genre  \
# 0   5331886                 Dhaka Dream            [Drama]
# 1   4853244               Rickshaw Girl           [Family]
# 2  15756034  Khachar Bhitor Ochin Pakhi         [Thriller]
# 3  15547790                  The Broker  [Drama, Thriller]
# 4  13770656                 August 1975          [History]
#
#                                             overview  runtime  \
# 0  Dhaka Dream is a tale of a city where outlying...      120
# 1  A Bangladeshi girl bravely attempts to help he...      102
# 2  In the game of politics, power dynamic can cha...      113
# 3  A poor man working as a broker struggles to ar...       47
# 4  The film portrays the initial events of the ra...      100
#
#                                                actor  \
# 0  Purnima Bristi| Anwar Hossain Chowdhury| Fazlu...
# 1           Allen Shubhro| Siam Ahmed| Novera Rahman
# 2     Fazlur Rahman Babu| Toma Mirza| Intekhab Dinar
# ...

# %%
def Convertactor(string):
    li = list(string.split("|"))
    return li

# %%
for i in range(0, len(movies)):
    str2 = Convertactor(movies['actor'][i])
    print(str2) 
    movies['actor'][i] = str2
# Out:
# ['Purnima Bristi', ' Anwar Hossain Chowdhury', ' Fazlul Haque']
# ['Allen Shubhro', ' Siam Ahmed', ' Novera Rahman']
# ['Fazlur Rahman Babu', ' Toma Mirza', ' Intekhab Dinar']
# ['Mosharraf Karim', ' Nazia Haque Orsha', ' Shahidullah Shabuj']
# ['Agun', ' Faruq Ahmed', ' Fazlur Rahman Babu']
# ['Azmeri Haque Badhon', ' Farzana Bithi', ' Yasir Al Haq']
# ['Noor Imran Mithu', ' Sheena Chohan', ' Likhon']
# ['Tapan Chatterjee', ' Rabi Ghosh', ' Ajoy Banerjee']
# ['Shankar Chakroborty', ' Indrani Halder', ' Rajit Kapoor']
# ['Chhabi Biswas', ' Karuna Baneerjee', ' Pahadi Sanyal']
# ['Soumitra Chatterjee', ' Aparna Sen', ' Rituparna Sengupta']
# ['Anil Chatterjee', ' Madhabi Mukherjee', ' Jaya Bachchan']
# ['Sharmila Tagore ', ' Kaberi Bose ', ' Simi Garewal']
# ['Soumitra Chatterjee ', ' Aparna Sen ', ' Rabi Ghosh']
# ['Anil Chatterjee ', ' Chandana Banerjee ', ' Aparna Sen']
# ['Pinaki Sengupta ', ' Smaran Ghosal ', ' Kamala Adhikari']
# ...

# %%
movies.head()
# Out:
#          id                       title              genre  \
# 0   5331886                 Dhaka Dream            [Drama]
# 1   4853244               Rickshaw Girl           [Family]
# 2  15756034  Khachar Bhitor Ochin Pakhi         [Thriller]
# 3  15547790                  The Broker  [Drama, Thriller]
# 4  13770656                 August 1975          [History]
#
#                                             overview  runtime  \
# 0  Dhaka Dream is a tale of a city where outlying...      120
# 1  A Bangladeshi girl bravely attempts to help he...      102
# 2  In the game of politics, power dynamic can cha...      113
# 3  A poor man working as a broker struggles to ar...       47
# 4  The film portrays the initial events of the ra...      100
#
#                                                actor  \
# 0  [Purnima Bristi,  Anwar Hossain Chowdhury,  Fa...
# 1       [Allen Shubhro,  Siam Ahmed,  Novera Rahman]
# 2  [Fazlur Rahman Babu,  Toma Mirza,  Intekhab Di...
# ...

# %%
def Convertdirector(string):
    li = list(string.split("|"))
    return li

# %%
for i in range(0, len(movies)):
    str3 = Convertdirector(movies['director'][i])
    print(str3) 
    movies['director'][i] = str3
# Out:
# ['Proshoon Rahman']
# ['Amitabh Reza Chowdhury']
# ['Raihan Rafi']
# ['Abu Hayat Mahmud']
# ['Selim Khan', ' Shamim Ahamed Roni']
# ['Abdullah Mohammad Saad']
# ['Mostofa Sarwar Farooki']
# ['Satayajit Roy']
# ['Buddhadev Dasgupta']
# ['Satayajit Roy']
# ['Aparna Sen']
# ['Satayajit Roy']
# ['Satayajit Roy']
# ['Dinen Gupta']
# ['Satayajit Roy']
# ['Satayajit Roy']
# ['Nirmal Dey']
# ['Satayajit Roy']
# ['Satayajit Roy']
# ['Satayajit Roy']
# ['Tapan Sinha']
# ['Satayajit Roy']
# ['Aparna Sen']
# ['Tareque Masud']
# ['Humayun Ahmed']
# ['Satayajit Roy']
# ['Shiboprosad Mukherjee ', ' Nandita Roy']
# ['Aniruddha Roy Chowdhury']
# ['Buddhadev Dasgupta']
# ['Goutam Ghoshe']
# ['Goutam Ghoshe']
# ['Agradoot']
# ['Aparna Sen']
# ['Rituparno Ghosh']
# ['Rituparno Ghosh']
# ['Ritwik Ghatak']
# ['Tareque Masud']
# ['Morshedul Islam']
# ['Mostofa Sarwar Farooki']
# ['Humayun Ahmed']
# ['Humayun Ahmed']
# ['Tanvir Mokammel']
# ['Rituparno Ghosh']
# ['Humayun Ahmed']
# ['Tauquir Ahmed']
# ...

# %%
movies.head()
# Out:
#          id                       title              genre  \
# 0   5331886                 Dhaka Dream            [Drama]
# 1   4853244               Rickshaw Girl           [Family]
# 2  15756034  Khachar Bhitor Ochin Pakhi         [Thriller]
# 3  15547790                  The Broker  [Drama, Thriller]
# 4  13770656                 August 1975          [History]
#
#                                             overview  runtime  \
# 0  Dhaka Dream is a tale of a city where outlying...      120
# 1  A Bangladeshi girl bravely attempts to help he...      102
# 2  In the game of politics, power dynamic can cha...      113
# 3  A poor man working as a broker struggles to ar...       47
# 4  The film portrays the initial events of the ra...      100
#
#                                                actor  \
# 0  [Purnima Bristi,  Anwar Hossain Chowdhury,  Fa...
# 1       [Allen Shubhro,  Siam Ahmed,  Novera Rahman]
# 2  [Fazlur Rahman Babu,  Toma Mirza,  Intekhab Di...
# ...

# %%
def Convertoverview(string):
    li = list(string.split("|"))
    return li

# %%
for i in range(0, len(movies)):
    str4 = Convertoverview(movies['overview'][i])
    #print(str4) 
    movies['overview'][i] = str4
# Out:
# C:\Users\USER\AppData\Local\Temp/ipykernel_11948/3941330472.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['overview'][i] = str4

# %%
movies['tags'] = movies['overview'] + movies['genre'] + movies['actor'] + movies['director']

# %%
new = movies.drop(columns=['overview','genre', 'actor','director'])
new.head()
# Out:
#          id                       title  runtime  rating  \
# 0   5331886                 Dhaka Dream      120     7.9
# 1   4853244               Rickshaw Girl      102     7.4
# 2  15756034  Khachar Bhitor Ochin Pakhi      113     8.3
# 3  15547790                  The Broker       47     8.1
# 4  13770656                 August 1975      100     7.8
#
#                                                 tags
# 0  [Dhaka Dream is a tale of a city where outlyin...
# 1  [A Bangladeshi girl bravely attempts to help h...
# 2  [In the game of politics, power dynamic can ch...
# 3  [A poor man working as a broker struggles to a...
# 4  [The film portrays the initial events of the r...

# %%
new['tags'][1]
# Out:
# ["A Bangladeshi girl bravely attempts to help her struggling family by disguising herself as a boy and driving her father's prized rickshaw for much needed extra money. Based on the acclaimed middle-grade novel by Mitali Perkins.",
#  'Family',
#  'Allen Shubhro',
#  ' Siam Ahmed',
#  ' Novera Rahman',
#  'Amitabh Reza Chowdhury']

# %%
new['tags'] = new['tags'].apply(lambda x: " ".join(x))
new.head()
# Out:
#          id                       title  runtime  rating  \
# 0   5331886                 Dhaka Dream      120     7.9
# 1   4853244               Rickshaw Girl      102     7.4
# 2  15756034  Khachar Bhitor Ochin Pakhi      113     8.3
# 3  15547790                  The Broker       47     8.1
# 4  13770656                 August 1975      100     7.8
#
#                                                 tags
# 0  Dhaka Dream is a tale of a city where outlying...
# 1  A Bangladeshi girl bravely attempts to help he...
# 2  In the game of politics, power dynamic can cha...
# 3  A poor man working as a broker struggles to ar...
# 4  The film portrays the initial events of the ra...

# %%
new['tags'] = new['tags'].apply(lambda x: x.lower())
new['tags'][1]
# Out:
# "a bangladeshi girl bravely attempts to help her struggling family by disguising herself as a boy and driving her father's prized rickshaw for much needed extra money. based on the acclaimed middle-grade novel by mitali perkins. family allen shubhro  siam ahmed  novera rahman amitabh reza chowdhury"

# %%
new.head()
# Out:
#          id                       title  runtime  rating  \
# 0   5331886                 Dhaka Dream      120     7.9
# 1   4853244               Rickshaw Girl      102     7.4
# 2  15756034  Khachar Bhitor Ochin Pakhi      113     8.3
# 3  15547790                  The Broker       47     8.1
# 4  13770656                 August 1975      100     7.8
#
#                                                 tags
# 0  dhaka dream is a tale of a city where outlying...
# 1  a bangladeshi girl bravely attempts to help he...
# 2  in the game of politics, power dynamic can cha...
# 3  a poor man working as a broker struggles to ar...
# 4  the film portrays the initial events of the ra...

# %%
import nltk
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def stem(text):
    y = []

    for i in text.split():
        y.append(ps.stem(i))
    return " ".join(y)

# %%
stem("a bangladeshi girl bravely attempts to help her struggling family by disguising herself as a boy and driving her father's prized rickshaw for much needed extra money. based on the acclaimed middle-grade novel by mitali perkins. family allen shubhro  siam ahmed  novera rahman amitabh reza chowdhury")
# Out:
# "a bangladeshi girl brave attempt to help her struggl famili by disguis herself as a boy and drive her father' prize rickshaw for much need extra money. base on the acclaim middle-grad novel by mitali perkins. famili allen shubhro siam ahm novera rahman amitabh reza chowdhuri"

# %%
new['tags'] = new['tags'].apply(stem)

# %%
new.head()
# Out:
#          id                       title  runtime  rating  \
# 0   5331886                 Dhaka Dream      120     7.9
# 1   4853244               Rickshaw Girl      102     7.4
# 2  15756034  Khachar Bhitor Ochin Pakhi      113     8.3
# 3  15547790                  The Broker       47     8.1
# 4  13770656                 August 1975      100     7.8
#
#                                                 tags
# 0  dhaka dream is a tale of a citi where outli pe...
# 1  a bangladeshi girl brave attempt to help her s...
# 2  in the game of politics, power dynam can chang...
# 3  a poor man work as a broker struggl to arrang ...
# 4  the film portray the initi event of the radic ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=1000,stop_words='english')

# %%
vector = cv.fit_transform(new['tags']).toarray()
vector.shape
# Out:
# (100, 1000)

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity = cosine_similarity(vector)

# %%
similarity
# Out:
# array([[1.        , 0.03217447, 0.07079923, ..., 0.14969624, 0.06816669,
#         0.05565226],
#        [0.03217447, 1.        , 0.04783649, ..., 0.        , 0.03349656,
#         0.03760222],
#        [0.07079923, 0.04783649, 1.        , ..., 0.01854716, 0.07370846,
#         0.06205716],
#        ...,
#        [0.14969624, 0.        , 0.01854716, ..., 1.        , 0.1948093 ,
#         0.29158268],
#        [0.06816669, 0.03349656, 0.07370846, ..., 0.1948093 , 1.        ,
#         0.32590732],
#        [0.05565226, 0.03760222, 0.06205716, ..., 0.29158268, 0.32590732,
#         1.        ]])

# %%
def recommend(movie):
    index = new[new['title'] == movie].index[0]
    distances = sorted(list(enumerate(similarity[index])),reverse=True,key = lambda x: x[1])
    for i in distances[1:6]:
        print(new.iloc[i[0]].title)

# %%
recommend('Noukadubi')
# Out:
# Kabuliwala
# Subhas Chandra
# Shabdo
# Aparajito
# Cholo Paltai

# %%
import pickle
pickle.dump(new,open('movie_list.pkl','wb'))
pickle.dump(similarity,open('similarity.pkl','wb'))
